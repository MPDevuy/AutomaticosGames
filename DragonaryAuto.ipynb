# %%
import pyautogui  #realiza clicks y mueve el mouse entre otras opciones
import subprocess
import unittest
from selenium.webdriver.common.keys import Keys
from selenium import webdriver
import time
#libreria pynput acciones del teclado
from pynput.keyboard import Key, Controller #realiza acciones del teclado

#variables para controlar el keyboar 
keyboard = Controller()

sleep = 40
t = 6  



def Dragonary():
    time.sleep(6)
    pyautogui.click(936, 637) #inicio batalla
    time.sleep(2)
    pyautogui.click(215, 408) #inicio batalla
    time.sleep(2)
    pyautogui.dragTo(20, 0, 2, button='left')  #inicio mover hacia batalla 12
    time.sleep(2)
    pyautogui.click(215, 508) #marcar 12
    time.sleep(4)
    pyautogui.click(1041, 596) #inicio batalla
    time.sleep(26)
    pyautogui.click(640, 466) #inicio
    time.sleep(3)
    pyautogui.click(493, 67) #automatico
    time.sleep(1)
    pyautogui.click(704, 68) #x2
    time.sleep(15)
    pyautogui.click(637, 619) #continuar1
    time.sleep(14)   
    pyautogui.click(637, 619) #continuar
    time.sleep(15) 
    pyautogui.click(637, 619) #continuar
    time.sleep(29) 
    pyautogui.click(637, 619) #continuar
   
    
def Dragonary2():
    time.sleep(32)
    pyautogui.click(936, 637) #inicio batalla
    time.sleep(2)
    pyautogui.click(215, 408) #inicio batalla
    time.sleep(2)
    pyautogui.dragTo(20, 0, 2, button='left')  #inicio mover hacia batalla 12
    time.sleep(2)
    pyautogui.click(215, 508) #marcar 12
    time.sleep(4)
    pyautogui.click(1041, 596) #inicio batalla
    time.sleep(23)
    pyautogui.click(640, 466) #inicio
    time.sleep(3)
    pyautogui.click(493, 67) #automatico
    time.sleep(2)
    pyautogui.click(704, 68) #x2
    time.sleep(15)
    pyautogui.click(637, 619) #continuar1
    time.sleep(13)   
    pyautogui.click(637, 619) #continuar
    time.sleep(14) 
    pyautogui.click(637, 619) #continuar
    time.sleep(15) 
    pyautogui.click(637, 619) #continuar
    time.sleep(30) 
   
    

    
#time.sleep(180) # cuando se queda sin cpu o inico despues de minado

for x in range  (0, 65): 
#    time.sleep(14)
    Dragonary()
    Dragonary2()
#    if x == t:
#        time.sleep(1500)
#        t = t + 4
